# %%
using DSP, WAV, PyPlot
# Out:
# ┌ Info: Precompiling PyPlot [d330b81b-6aea-500a-939a-2ce795aea3ee]
# └ @ Base loading.jl:1278

# %%
using SampledSignals, Waveforms

# %%
include("MusicTools.jl")
# Out:
# Main.MusicTools

# %%
begin
    env = MusicTools.envalope([0,1,0],[4100,40000])
    SampledSignals.SampleBuf(trianglewave.(LinRange(0, 2*pi*220, 44100)).*env, 44100)
end
# Out:
# 44100-frame, 1-channel SampleBuf{Float64, 1}
# 1.0s sampled at 44100.0Hz
# ▅▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▅▅▅▅▅▅▅▅▄▄▄▃▃

# %%
[range(0, 1, length=4100); range(1, 0, length=40000)]
# Out:
# 44100-element Array{Float64,1}:
#  0.0
#  0.00024396194193705782
#  0.00048792388387411563
#  0.0007318858258111735
#  0.0009758477677482313
#  0.0012198097096852891
#  0.001463771651622347
#  0.0017077335935594047
#  0.0019516955354964625
#  0.0021956574774335204
#  0.0024396194193705783
#  0.002683581361307636
#  0.002927543303244694
#  ⋮
#  0.0002750068751718793
#  0.0002500062501562539
#  0.00022500562514062852
#  0.00020000500012500312
#  0.00017500437510937773
#  0.00015000375009375234
#  0.00012500312507812694
#  0.00010000250006250156
#  7.500187504687617e-5
#  5.000125003125078e-5
#  2.500062501562539e-5
#  0.0

# %%
plot(env)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fa93be0b7c0>
